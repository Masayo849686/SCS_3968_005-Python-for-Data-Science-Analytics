# %% [markdown]
# # Python for Data Science - Assignment 3
#
# ## Assignment Objectives
#
# The objectives of this assignment are to test your understanding of the Pandas library, including:
#
# * Creating DataFrames from csv files
# * Manipulating DataFrames to identify meaningful insights
# * Interpreting and communicating insights
#
#
# ## Assignment Instructions
#
# For each of the questions below, write Python code to produce the answer. Be sure to run your code and display the output.
#
# To submit the assignment, save your Jupyter notebook and submit the file in Quercus. You do not need to submit the csv data file.
#
# ## Dataset Description
#
# This dataset represents the top 100 most streamed songs on Spotify, with various characteristics listed for each song. Your task is to conduct a deep dive into the dataset to understand the drivers of popular songs (i.e., what makes a song popular?). You can find descriptions of each field at the following Kaggle link: https://www.kaggle.com/pavan9065/top-100-most-streamed-songs-on-spotify/version/1

# %% [markdown]
# ### Question 1 (5 marks):
#
# Import and review the data file provided. What conclusions can you make based on your observations about the full data set (for example, are there any missing data points? What do the summary metrics indicate?)

# %%
import pandas as pd

# %%
songs = pd.customers = pd.read_csv('3968_Assignment_3_Top 100 most Streamed - Sheet1.csv')

# %%
songs.head()
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity
# ...

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             100 non-null    object
#  1   artist            100 non-null    object
#  2   top genre         100 non-null    object
#  3   year              100 non-null    int64
#  4   beats.per.minute  100 non-null    int64
#  5   energy            100 non-null    int64
#  6   danceability      100 non-null    int64
#  7   loudness.dB       100 non-null    int64
#  8   liveness          100 non-null    int64
#  9   valance           100 non-null    int64
#  10  length            100 non-null    int64
#  11  acousticness      100 non-null    int64
#  12  speechiness       100 non-null    int64
#  13  popularity        100 non-null    int64
# dtypes: int64(11), object(3)
# memory usage: 11.1+ KB

# %%
songs.describe()
# Out:
#               year  beats.per.minute      energy  danceability  loudness.dB  \
# count   100.000000        100.000000  100.000000     100.00000   100.000000
# mean   2015.960000        116.970000   62.680000      66.96000    -6.100000
# std       5.327497         27.470629   16.491737      13.60401     1.987334
# min    1975.000000         71.000000   11.000000      35.00000   -14.000000
# 25%    2015.000000         95.000000   52.000000      59.00000    -7.000000
# 50%    2017.000000        115.000000   64.500000      69.00000    -6.000000
# 75%    2018.000000        135.250000   76.000000      77.00000    -5.000000
# max    2021.000000        186.000000   92.000000      91.00000    -3.000000
#
#          liveness     valance      length  acousticness  speechiness  \
# count  100.000000  100.000000  100.000000     100.00000   100.000000
# mean    16.860000   49.970000  214.530000      24.95000     9.930000
# std     12.972403   21.737857   35.934974      26.27876     9.424077
# ...

# %% [markdown]
# ### Question 2 (5 marks):
#
# Calculate summary statistics for each genre. What can you conclude?

# %%
genre_stats = songs.groupby('top genre').describe()

# %%
genre_stats
# Out:
#                            year                                          \
#                           count         mean       std     min      25%
# top genre
# acoustic pop                1.0  2008.000000       NaN  2008.0  2008.00
# alternative rock            1.0  2004.000000       NaN  2004.0  2004.00
# australian dance            1.0  2016.000000       NaN  2016.0  2016.00
# australian pop              1.0  2019.000000       NaN  2019.0  2019.00
# beatlesque                  1.0  1995.000000       NaN  1995.0  1995.00
# boy band                    1.0  2018.000000       NaN  2018.0  2018.00
# brostep                     1.0  2018.000000       NaN  2018.0  2018.00
# cali rap                    1.0  2021.000000       NaN  2021.0  2021.00
# canadian contemporary r&b   4.0  2016.500000  2.380476  2015.0  2015.00
# canadian hip hop            2.0  2017.000000  1.414214  2016.0  2016.50
# canadian pop                6.0  2016.000000  1.673320  2015.0  2015.00
# ...

# %% [markdown]
# ### Question 3 (5 marks):
#
# Conduct detailed analysis to understand what 'popular' songs have in common. If you had to make a recommendation to an up-and-coming artist about their music, what would your recommendation be based on the data?

# %%
popularity_rank = songs.sort_values('popularity', ascending=False)
popularity_rank.head()
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 2                91      72            70           -4        32       73
# 1                95      82            55           -4        34       56
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity
# ...

# %%
common_chara = popularity_rank[['title', 'artist', 'top genre', 'beats.per.minute', 'energy', 'danceability', 'loudness.dB', 'valance', 'length', 'popularity']].head(10)
common_chara
# Out:
#                     title           artist                  top genre  \
# 0         Blinding Lights       The Weeknd  canadian contemporary r&b
# 2  Mood (feat. iann dior)         24kGoldn                   cali rap
# 1        Watermelon Sugar     Harry Styles                        pop
# 3       Someone You Loved    Lewis Capaldi                        pop
# 4                 Perfect       Ed Sheeran                        pop
# 5                Believer  Imagine Dragons                modern rock
# 6    lovely (with Khalid)    Billie Eilish                 electropop
# 7                 Circles      Post Malone                    dfw rap
# 8            Shape of You       Ed Sheeran                        pop
# 9                Memories         Maroon 5                        pop
#
#    beats.per.minute  energy  danceability  loudness.dB  valance  length  \
# 0               171      73            51           -6       33     200
# ...
